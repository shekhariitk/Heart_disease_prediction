# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
heart_df = pd.read_csv("/content/sample_data/heart_disease.csv")

# %%
heart_df
# Out:
#       Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0       Male   39   postgraduate              0         0.0     0.0
# 1     Female   46  primaryschool              0         0.0     0.0
# 2       Male   48     uneducated              1        20.0     0.0
# 3     Female   61       graduate              1        30.0     0.0
# 4     Female   46       graduate              1        23.0     0.0
# ...      ...  ...            ...            ...         ...     ...
# 4233    Male   50     uneducated              1         1.0     0.0
# 4234    Male   51       graduate              1        43.0     0.0
# 4235  Female   48  primaryschool              1        20.0     NaN
# 4236  Female   44     uneducated              1        15.0     0.0
# 4237  Female   52  primaryschool              0         0.0     0.0
#
#      prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# ...

# %%
heart_df.shape
# Out:
# (4238, 16)

# %%
heart_df.head()
# Out:
#    Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0    Male   39   postgraduate              0         0.0     0.0
# 1  Female   46  primaryschool              0         0.0     0.0
# 2    Male   48     uneducated              1        20.0     0.0
# 3  Female   61       graduate              1        30.0     0.0
# 4  Female   46       graduate              1        23.0     0.0
#
#   prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0              no             0         0    195.0  106.0   70.0  26.97
# 1              no             0         0    250.0  121.0   81.0  28.73
# 2              no             0         0    245.0  127.5   80.0  25.34
# 3              no             1         0    225.0  150.0   95.0  28.58
# 4              no             0         0    285.0  130.0   84.0  23.10
#
#    heartRate  glucose Heart_ stroke
# 0       80.0     77.0            No
# 1       95.0     76.0            No
# ...

# %%
heart_df.drop(columns=['education'],inplace=True)

# %%
heart_df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4235  Female   48              1        20.0     NaN              no
# 4236  Female   44              1        15.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
heart_df.dropna(inplace=True)

# %%
heart_df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds prevalentStroke  \
# 0       Male   39              0         0.0     0.0              no
# 1     Female   46              0         0.0     0.0              no
# 2       Male   48              1        20.0     0.0              no
# 3     Female   61              1        30.0     0.0              no
# 4     Female   46              1        23.0     0.0              no
# ...      ...  ...            ...         ...     ...             ...
# 4231    Male   58              0         0.0     0.0              no
# 4232    Male   68              0         0.0     0.0              no
# 4233    Male   50              1         1.0     0.0              no
# 4234    Male   51              1        43.0     0.0              no
# 4237  Female   52              0         0.0     0.0              no
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
heart_df['Gender'] =heart_df['Gender'].replace(['Male','Female'],[1,0])

# %%
heart_df['prevalentStroke'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
heart_df['prevalentStroke'] = heart_df['prevalentStroke'].replace(['yes','no'],[1,0])

# %%
heart_df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
heart_df['Heart_ stroke'] = heart_df['Heart_ stroke'].replace(['yes','No'],[1,0])

# %%
heart_df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3749 entries, 0 to 4237
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           3749 non-null   int64
#  1   age              3749 non-null   int64
#  2   currentSmoker    3749 non-null   int64
#  3   cigsPerDay       3749 non-null   float64
#  4   BPMeds           3749 non-null   float64
#  5   prevalentStroke  3749 non-null   int64
#  6   prevalentHyp     3749 non-null   int64
#  7   diabetes         3749 non-null   int64
#  8   totChol          3749 non-null   float64
#  9   sysBP            3749 non-null   float64
#  10  diaBP            3749 non-null   float64
#  11  BMI              3749 non-null   float64
#  12  heartRate        3749 non-null   float64
#  13  glucose          3749 non-null   float64
#  14  Heart_ stroke    3749 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 468.6 KB

# %%
heart_df.reset_index(inplace=True)

# %%
heart_df
# Out:
#       index  Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0         0       1   39              0         0.0     0.0                0
# 1         1       0   46              0         0.0     0.0                0
# 2         2       1   48              1        20.0     0.0                0
# 3         3       0   61              1        30.0     0.0                0
# 4         4       0   46              1        23.0     0.0                0
# ...     ...     ...  ...            ...         ...     ...              ...
# 3744   4231       1   58              0         0.0     0.0                0
# 3745   4232       1   68              0         0.0     0.0                0
# 3746   4233       1   50              1         1.0     0.0                0
# 3747   4234       1   51              1        43.0     0.0                0
# 3748   4237       0   52              0         0.0     0.0                0
#
# ...

# %%
heart_df.drop(columns=['index'],inplace=True)

# %%
heart_df
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 3744       1   58              0         0.0     0.0                0
# 3745       1   68              0         0.0     0.0                0
# 3746       1   50              1         1.0     0.0                0
# 3747       1   51              1        43.0     0.0                0
# 3748       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
input_data = heart_df.drop(columns=['Heart_ stroke'])
output_data = heart_df['Heart_ stroke']

# %%
output_data.value_counts()
# Out:
# Heart_ stroke
# 0    3177
# 1     572
# Name: count, dtype: int64

# %%
# DATA RESAMPLING

# %%
from imblearn.over_sampling import SMOTE

# %%
sn = SMOTE(random_state=2)

# %%
input_data , output_data = sn.fit_resample(input_data,output_data.ravel())

# %%
np.unique(output_data,return_counts=True)
# Out:
# (array([0, 1]), array([3177, 3177]))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train , x_test ,y_train , y_test = train_test_split(input_data,output_data,test_size=0.2)

# %%
x_test
# Out:
#       Gender  age  currentSmoker  cigsPerDay    BPMeds  prevalentStroke  \
# 4824       1   62              1   25.000000  0.000000                0
# 3034       0   50              1    3.000000  0.000000                0
# 4992       0   51              0    0.000000  0.914902                0
# 182        0   55              1    9.000000  0.000000                0
# 3552       0   46              1    1.000000  0.000000                0
# ...      ...  ...            ...         ...       ...              ...
# 5056       1   40              1   19.271927  0.000000                0
# 950        1   40              0    0.000000  0.000000                0
# 5103       0   46              0    0.000000  0.000000                0
# 4682       1   51              1   24.868317  0.000000                0
# 2243       1   46              0    0.000000  0.000000                0
#
#       prevalentHyp  diabetes     totChol       sysBP       diaBP        BMI  \
# ...

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict = model.predict(x_test)

# %%
predict
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
model.score(x_test, y_test)
# Out:
# 0.6412273800157356

# %%
import pickle as pk

# %%
pk.dump(model,open('model.pkl','wb'))

# %%
loaded_model = pk.load(open('model.pkl','rb'))
